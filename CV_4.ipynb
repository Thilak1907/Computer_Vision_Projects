# %%
# !pip install torch torchvision matplotlib opencv-python
# !pip install git+https://github.com/ultralytics/yolov5
# Out:
# ...
#   Cloning https://github.com/ultralytics/yolov5 to /tmp/pip-req-build-j3sgkkg4
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/yolov5 /tmp/pip-req-build-j3sgkkg4
#   Resolved https://github.com/ultralytics/yolov5 to commit 5cdad8922c83b0ed49a0173cd1a8b0739acbb336
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import cv2
import torch
from google.colab.patches import cv2_imshow  # Import cv2_imshow

# Load a pre-trained YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5m')

# Load the image
image_path = '/content/stock-photo.jpg'

image = cv2.imread(image_path)

original = image.copy() # Assign a copy of the original image to original

# Perform inference on the image
results = model(image)

# Render results (bounding boxes and labels)
image_with_boxes = results.render()[0]

# Ensure both images have the same data type
original = original.astype(image_with_boxes.dtype)

side_by_side = cv2.hconcat([original, image_with_boxes])

# Display the side-by-side images using cv2_imshow
cv2_imshow(side_by_side)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-2-19 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 21172173 parameters, 0 gradients, 48.9 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=728x248>
